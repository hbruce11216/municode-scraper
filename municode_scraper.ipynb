# %% [markdown]
# # Municode Scraper
# This scraper has 3 functions
# - list_of_towns() scrapes the State-wide webpage and returns a single-column dataframe containing the links to each town/county's webpage on Municode
# - identify_comparison_table_URL_part1() scrapes the town/county webpage and identifies the part of the webpage that contains information about state vs local law codes
#     - This needs to be improved for accuracy. I currently wrote it to just take the last url on the page but that should be amended to actually search for the page that holds the table comparing state and local law codes. The subpages that hold this table have different names depending on the county.
# - scraper() takes in the subpage url that was identified in identify_comparison_table_URL_part1() and scrapes the webpage, returning a two-column dataframe with the State law codes in the first column and the corresponding town/county law codes in the second column
#     - This needs to be improved for specificity around what is being scraped. Some subpages contain multiple tables, some contain tables of different dimensions (4 columns instead of 2 columns) -- these differences need to be accounted for so that the right information is being returned in the dataframe.

# %%
import pandas as pd 
import os 
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
import requests

# %%
def list_of_towns():
    driver = webdriver.Chrome('/Users/holdenbruce/Downloads/chromedriver3')

    # set implicit wait time so that apis/javascript load before we scrape 
    driver.implicitly_wait(5) # seconds

    # url of the county
    url = f"https://library.municode.com/VA"
    # headers to let them know who i am
    headers = {'user-agent': 'class project (hab6xf@virginia.edu)'}
    # xpath of the table in the webpage created by javascript 
    xpathHOME = "/html/body/div[1]/div[2]/ui-view/div[2]/section/div/div"

    driver.get(url)

    # use xpath to get to the table
    data = driver.find_elements_by_xpath(xpathHOME)
    # links = driver.find_elements_by_tag_name("a")
    
    # add a delay of 3 seconds in the function
    time.sleep(2)
    
    # use outerHTML to maintain the html/css/javasript code pulled from the webpage 
    html = data[0].get_attribute("outerHTML")

    r1 = re.findall(r"https://library.municode.com/VA/[\w\.-]+",html)

    # convert to dataframe and drop duplicates
    towns_list = pd.DataFrame(r1)
    towns_list = towns_list.drop_duplicates().reset_index(drop=True)

    return towns_list

# %%
town_urls = list_of_towns()
town_urls = town_urls.rename(columns={0:"urls"})
town_urls
# Out:
#                                                  urls
# 0     https://library.municode.com/VA/accomack_county
# 1    https://library.municode.com/VA/albemarle_county
# 2          https://library.municode.com/VA/alexandria
# 3    https://library.municode.com/VA/alleghany_county
# 4           https://library.municode.com/VA/altavista
# ..                                                ...
# 142        https://library.municode.com/VA/winchester
# 143           https://library.municode.com/VA/windsor
# 144       https://library.municode.com/VA/wise_county
# 145         https://library.municode.com/VA/woodstock
# 146        https://library.municode.com/VA/wytheville
#
# [147 rows x 1 columns]

# %%
def identify_comparison_table_URL_part1(url):
    driver = webdriver.Chrome('/Users/holdenbruce/Downloads/chromedriver3')

    # set implicit wait time so that apis/javascript load before we scrape 
    driver.implicitly_wait(5) # seconds

    # url of the county
    # url = f"https://library.municode.com/va/{town}/codes/code_of_ordinances"
    # headers to let them know who i am
    # headers = {'user-agent': 'class project (hab6xf@virginia.edu)'}
    # xpath of the table in the webpage created by javascript 
    xpath = "/html/body/div[1]/div[2]/ui-view/mcc-codes/div[2]/section[1]/div[2]"

    driver.get(url)

    # use xpath to get to the table
    data = driver.find_elements_by_xpath(xpath)
    # links = driver.find_elements_by_tag_name("a")
    
    
    # add a delay of 3 seconds in the function
    time.sleep(2)
    
    
    # use outerHTML to maintain the html/css/javasript code pulled from the webpage 
    html = data[0].get_attribute("outerHTML")

    r2 = re.findall(r'(https?://[^\s]+)', html)
    
    url = r2[-1]
    url = url[:-1]
    
    return url

# %%
identify_comparison_table_URL_part1(town_urls.loc[0,'urls'])
# Out:
# 'https://library.municode.com/va/accomack_county/codes/code_of_ordinances?nodeId=STLARETA'

# %%
def scraper(url,town):
    driver = webdriver.Chrome('/Users/holdenbruce/Downloads/chromedriver3')

    # set implicit wait time so that apis/javascript load before we scrape 
    driver.implicitly_wait(5) # seconds

    # url of the county
    url = identify_comparison_table_URL_part1(url)
    print("url:",url)
    
    # define the nodeID by taking the last piece of the ULR after the "="
    nodeID = url.split("=")[-1]
    
    # define the nodeIDs that we care about (discovered by team through manual check of Municode)
    nodeIDs = [
        'STLARETA',
        'STATE_LAW_REFERENCE_TABLE',
        'COOR_STRETA',
        'STRETA',
        'THCH_STRETA'
    ]
    
    # if nodeID not what we want, break
    if nodeID not in nodeIDs:
        print(f"pass: {town} empty")
        # define an empty dataframe
        df_empty = pd.DataFrame({'town' : []})
        
        # now write that empty dataframe to CSV
        df.to_csv(f'countyCSV/{town}.csv', index=False)  
        pass
    
    # if nodeID what we want, do this
    else:
        # xpath of the table in the webpage created by javascript 
        xpath = "/html/body/div[1]/div[2]/ui-view/mcc-codes/div[2]/section/div[1]/mcc-codes-content/div/div[2]/ul/li/mcc-codes-content-chunk/div/div/div[2]/div/div/div/div[2]/table"
        driver.get(url)

        # use xpath to get to the table
        data = driver.find_elements_by_xpath(xpath)
        #print("data:",data)
        #if 

        # use outerHTML to maintain the html/css/javasript code pulled from the webpage 
        table = data[0].get_attribute("outerHTML")
        #print("table:",table)

        # https://stackoverflow.com/questions/41214702/parse-html-and-read-html-table-with-selenium-python

        # convert that table into a pandas dataframe
        df = pd.read_html(table)
        df = df[0]


        # rename the columns
        df = df.rename(columns={'Code of Virginia  Section': "Virginia", "Section this Code":town})

        #print(url)

        # now write to CSV
        df.to_csv(f'countyCSV/{town}.csv', index=False)  

        return df

# %%
# scraper('https://library.municode.com/va/accomack_county',"accomack_county")

# %% [markdown]
# # Could also import municode.py

# %%
# loop through all of the towns 
# for ind in list_of_towns.index:
for ind in town_urls.index:
    url = town_urls.loc[ind,'urls']
    town = town_urls.loc[ind,'urls'].split("/")[-1]
    
    try:
        print(scraper(url,town))
    except:
        print(f'This municipality {town} does not host the necessary documents online.')
# Out:
# url: https://library.municode.com/va/accomack_county/codes/code_of_ordinances?nodeId=STLARETA
#                              0                  1
# 0    Code of Virginia  Section  Section this Code
# 1                 1-13 et seq.              Ch. 1
# 2                       1-13.3                1-2
# 3               1-13.6, 1-13.7                1-2
# 4                       1-13.9                1-4
# ..                         ...                ...
# 401              62.1-44.15:46              38-98
# 402           62.1-148 et seq.   Ch. 102, Art. II
# 403                   62.1-255            106-376
# 404                   63.1-164              22-88
# 405          68.1-1200 et seq.              22-88
#
# [406 rows x 2 columns]
# This municipality albemarle_county does not host the necessary documents online.
# This municipality alexandria does not host the necessary documents online.
# url: https://library.municode.com/va/alleghany_county/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                  1-13 et seq.                1-2
# 2                        1-13.9                1-3
# 3              2.2-3700 et seq.              Ch. 2
# 4                      2.2-4027              52-14
# ..                          ...                ...
# 387               62.1-44.15:35               52-7
# 388               62.1-44.15:40              52-12
# 389                     63.1-17             66-678
# 390                    63.1-172              66-93
# 391                         NaN             66-168
#
# [392 rows x 2 columns]
# url: https://library.municode.com/va/altavista/codes/code_of_ordinances?nodeId=STLARETA
#     Code of  Virginia  Section altavista
# 0                 1-13 et seq.       1-2
# 1                 1-13—1-13.34       1-2
# 2                     1-13.1:1       1-2
# 3                       1-13.9       1-3
# 4                      1-13.19       1-2
# ..                         ...       ...
# 647          62.1-44.2 et seq.    Ch. 78
# 648                  62.1-44.3      78-3
# 649                   62.1-194    62-118
# 650                   63.1-164     70-43
# 651                  63.2-2200     86-22
#
# [652 rows x 2 columns]
# url: https://library.municode.com/va/amherst/codes/code_of_ordinances?nodeId=STLARETA
#     Code of Virginia Section           amherst
# 0                  1-13.39.2              20-3
# 1              1-200 et seq.               1-2
# 2           2.2-4367 et seq.              2-56
# 3                  title 3.2             Ch. 4
# 4           3.2-6500 et seq.    Ch. 4, Art. II
# ..                       ...               ...
# 201                58.1-3984             8-213
# 202                        —             8-220
# 203                58.1-3986             8-209
# 204                58.1-3993             8-209
# 205        58.1-3700 et seq.  Ch. 8, Art. VIII
#
# [206 rows x 2 columns]
# url: https://library.municode.com/va/amherst_county/codes/code_of_ordinances?nodeId=STRETA
#                                     0        1                   2
# 0  Constitution  of Virginia  Article  Section  Section  this Code
# 1                                  VI        1                 1-5
# 2                                 NaN        2                 1-5
# This municipality ashland does not host the necessary documents online.
# This municipality bedford does not host the necessary documents online.
# url: https://library.municode.com/va/bedford_county/codes/code_of_ordinances?nodeId=STRETA
#                         0                  1
# 0    Code of Va.  Section  Section this Code
# 1             1-13.1—1-15                1-2
# 2               1-13.39.2               11-1
# 3           1-202 et seq.                1-2
# 4                   1-217                1-3
# ..                    ...                ...
# 364         62.1-44.15:51                7-1
# 365         62.1-44.15:52                7-4
# 366         62.1-44.15:56                7-4
# 367           63.1-85.3:1               4-50
# 368              63.1-142               4-50
#
# [369 rows x 2 columns]
# This municipality berryville does not host the necessary documents online.
# url: https://library.municode.com/va/big_stone_gap/codes/code_of_ordinances?nodeId=STLARETA
# This municipality big_stone_gap does not host the necessary documents online.
# url: https://library.municode.com/va/blacksburg/codes/code_of_ordinances?nodeId=CD_COMPARATIVE_TABLEOR
# pass: blacksburg empty
# This municipality blacksburg does not host the necessary documents online.
# url: https://library.municode.com/va/blackstone/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                  1-10 et seq.              Ch. 1
# 2                        1-13.1                1-2
# 3                1-13.1—1-13.36                1-2
# 4                      1-13.1:1                1-2
# ..                          ...                ...
# 387                    59.1-121             Ch. 42
# 388            59.1-131 et seq.             Ch. 42
# 389            59.1-137 et seq.             Ch. 30
# 390            59.1-142 et seq.             Ch. 30
# 391           62.1-44.2 et seq.             Ch. 62
#
# [392 rows x 2 columns]
# This municipality bland_county does not host the necessary documents online.
# url: https://library.municode.com/va/bluefield/codes/code_of_ordinances?nodeId=STLARETA
#                      0                  1
# 0    Code of  Virginia  Section this Code
# 1       1.13-1 et seq.                1-2
# 2               1.13-3                1-2
# 3             1.13-3:1                1-2
# 4       1.13-6, 1.13-7                1-2
# ..                 ...                ...
# 381          58.1-8230             50-252
# 382  59.1-68.6 et seq.              2-195
# 383   59.1-270 et seq.              4-151
# 384   59.1-538 et seq.              4-151
# 385  62.1-44.2 et seq.              62-73
#
# [386 rows x 2 columns]
# url: https://library.municode.com/va/botetourt_county/codes/code_of_ordinances?nodeId=STRETA
#                          0                  1
# 0     Code of Va.  Section  Section this Code
# 1                   1-13-3                1-2
# 2                   1-13.9                1-3
# 3                     1-17                1-5
# 4                  2.1-344               2-21
# ..                     ...                ...
# 437                    NaN              10-54
# 438          62.1-44.15:35              10-56
# 439          62.1-44.15:40              10-61
# 440  62.1-44.15:51 et seq.              10-21
# 441               63.1-195               25-5
#
# [442 rows x 2 columns]
# This municipality bristol does not host the necessary documents online.
# url: https://library.municode.com/va/brunswick_county/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                        1-13.3                1-2
# 2                1-13.6, 1-13.7                1-2
# 3                        1-13.9                1-4
# 4              1-13.15, 1-13.16                1-2
# ..                          ...                ...
# 220                         NaN              30-37
# 221            62.1-44.15:63(A)              30-37
# 222                62.1-44.19:3              30-61
# 223                         NaN              30-73
# 224                    62.1-255             App. B
#
# [225 rows x 2 columns]
# url: https://library.municode.com/va/buena_vista/codes/code_of_ordinances?nodeId=STATE_LAW_REFERENCE_TABLE
#                               0                     1
# 0     Code of Virginia  Section    Section  this Code
# 1                 1-200 et seq.                   1-2
# 2                         1-217                   1-3
# 3                     2.2-614.3        Ch. 10, Art. V
# 4                      2.2-1112                32-134
# ...                         ...                   ...
# 1118              62.1-44.15:27  LDR 1801.00, 1801.04
# 1119             62.1-44.15:34A           LDR 1801.23
# 1120              62.1-44.15:35           LDR 1801.06
# 1121              62.1-44.15:40           LDR 1801.14
# 1122              62.1-44.15:44           LDR 1801.16
#
# [1123 rows x 2 columns]
# This municipality cape_charles does not host the necessary documents online.
# This municipality charles_city_county does not host the necessary documents online.
# This municipality charlottesville does not host the necessary documents online.
# url: https://library.municode.com/va/chase_city/codes/code_of_ordinances?nodeId=ORDINANCE_DISPOSITION_TABLE
# pass: chase_city empty
# This municipality chase_city does not host the necessary documents online.
# url: https://library.municode.com/va/chatham/codes/code_of_ordinances?nodeId=STLARETA
#                   Virginia Section  this Code
# 0                    1-200           1.01.010
# 1                    1-243           1.13.010
# 2         2.2-3100 et seq.   Tit. 2, Ch. 2.04
# 3    2.2-3100—  2.2-3112.A           2.05.050
# 4                 2.2-3101           2.05.020
# ..                     ...                ...
# 107              58.1-3840   Tit. 3, Ch. 3.05
# 108              58.1-3906           3.05.100
# 109              58.1-3958           3.09.010
# 110       59.1-137 et seq.   Tit. 8, Ch. 8.04
# 111           62.1-44.18:2        13.04.610.3
#
# [112 rows x 2 columns]
# This municipality chesapeake does not host the necessary documents online.
# url: https://library.municode.com/va/chesterfield_county/codes/code_of_ordinances?nodeId=STLARETA
#     Code of  Virginia  Section      chesterfield_county
# 0                       1-13.3                      1-2
# 1                       1-13.7                      1-2
# 2                      1-13.19                      1-2
# 3                    1-13.39:2                     13-1
# 4                       art. 2              Char. § 9.5
# ..                         ...                      ...
# 463           62.1-44.15:58(C)                     8-32
# 464      62.1-44.15:67 et seq.                      8-2
# 465                    ch. 63b    Ch. 18, Art. VII, § 3
# 466                    ch. 233  Ch. 18, Art. VII, § 7-c
# 467                        NaN  Ch. 28, Art. VII, § 7-c
#
# [468 rows x 2 columns]
# url: https://library.municode.com/va/christiansburg/codes/code_of_ordinances?nodeId=STLARETA
#           Virginia Section  this Code
# 0              1-1                1-2
# 1            1-210                1-2
# 2            1-216                1-2
# 3            1-217                1-3
# 4            1-220               34-3
# ..             ...                ...
# 395            NaN              16-29
# 396  62.1-44.15:64              16-30
# 397  62.1-44.15:65              16-22
# 398     62.1-44.26              16-66
# 399      64.2-1502       Char. § 3.20
#
# [400 rows x 2 columns]
# url: https://library.municode.com/va/clifton_forge/codes/code_of_ordinances?nodeId=STLARETA
#               Virginia Section  this Code
# 0                  1-1                1-2
# 1        1-200 et seq.                1-2
# 2                1-210                1-2
# 3                1-216                1-2
# 4                1-217                1-3
# ..                 ...                ...
# 172          15.2-2024      Ch. 22 (note)
# 173          15.2-2026      Ch. 74 (note)
# 174          15.2-2029      Ch. 74 (note)
# 175                  —      Ch. 82 (note)
# 176  15.2-2100 et seq.      Ch. 26 (note)
#
# [177 rows x 2 columns]
# This municipality colonial_beach does not host the necessary documents online.
# url: https://library.municode.com/va/covington/codes/code_of_ordinances?nodeId=STLARETA
#           Virginia Section  this Code
# 0    1-200 et seq.                1-2
# 1            1-217                1-5
# 2            1-239                1-7
# 3            1-243                1-8
# 4           2.1-21                1-2
# ..             ...                ...
# 393  62.1-44.15:52               18-3
# 394              —              18-25
# 395  62.1-44.15:53               18-3
# 396  62.1-44.15:54               18-3
# 397  62.1-44.15:56              18-25
#
# [398 rows x 2 columns]
# url: https://library.municode.com/va/craig_county/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                        1-13.3                1-2
# 2                1-13.6, 1-13.7                1-2
# 3                        1-13.9                1-3
# 4              1-13.15, 1-13.16                1-2
# ..                          ...                ...
# 206               62.1-44.15:35               47-6
# 207               62.1-44.15:40              47-11
# 208                    62.1-255               58-6
# 209                    63.1-120               14-3
# 210                      1613.1               14-4
#
# [211 rows x 2 columns]
# url: https://library.municode.com/va/crewe/codes/code_of_ordinances?nodeId=STLARETA
#                   Virginia Section  this Code
# 0                   1-3.23                1-2
# 1           1-13.6, 1-13.7                1-2
# 2                  1-13.13                1-2
# 3         1-13.15, 1-13.16                1-2
# 4                  1-13.23                1-2
# ..                     ...                ...
# 395              58.1-3993             66-186
# 396       59.1-137 et seq.      Ch. 38 (note)
# 397              59.1-3700             66-181
# 398      62.1-44.2 et seq.      Ch. 74 (note)
# 399  62.1-44.15:51 et seq.      Ch. 34 (note)
#
# [400 rows x 2 columns]
# This municipality culpeper does not host the necessary documents online.
# url: https://library.municode.com/va/culpeper_county/codes/code_of_ordinances?nodeId=STRETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                         1-202                1-2
# 2                         1-217                1-3
# 3                      2.2-3101               9-56
# 4                      2.2-3112               9-49
# ..                          ...                ...
# 193                         NaN                8-9
# 194               62.1-44.15:56               8-32
# 195                  62.1-44.32              14-78
# 196                    64.2-509               2-10
# 197                    64.2-510               2-10
#
# [198 rows x 2 columns]
# This municipality cumberland_county does not host the necessary documents online.
# url: https://library.municode.com/va/damascus/codes/code_of_ordinances?nodeId=STLARETA
#                            0                  1
# 0    Code of VirginiaSection  Section this Code
# 1                     1-13.3                1-2
# 2             1-13.6, 1-13.7                1-2
# 3                     1-13.9                1-3
# 4                    1-13.15                1-2
# ..                       ...                ...
# 207                      NaN             22-293
# 208                58.1-3940             22-295
# 209        58.1-3940 et seq.          Char. § 5
# 210                58.1-3984     22-295, 22-296
# 211               58.14-3701             22-291
#
# [212 rows x 2 columns]
# This municipality danville does not host the necessary documents online.
# url: https://library.municode.com/va/dayton/codes/code_of_ordinances?nodeId=STLARETA
#           Virginia Section  this Code
# 0    1-200 et seq.                1-2
# 1    1-203 et seq.                1-2
# 2            1-210                1-2
# 3            1-213                1-2
# 4            1-216                1-2
# ..             ...                ...
# 335      58.1-3984     22-101, 22-102
# 336      58.1-3986             22-100
# 337      58.1-3993             22-100
# 338      59.1-3728             22-105
# 339     62.1-44.32             26-232
#
# [340 rows x 2 columns]
# url: https://library.municode.com/va/dinwiddie_county/codes/code_of_ordinances?nodeId=STRETA
#                          0                  1
# 0     Code of Va.  Section  Section this Code
# 1            1-202 et seq.                1-2
# 2                    1-217                1-3
# 3                 2.2-4027              21-54
# 4         2.2-4300 et seq.     Ch. 2, Art. IV
# ..                     ...                ...
# 328       62.1-44.15:58(A)                9-8
# 329       62.1-44.15:58(C)               9-18
# 330  62.1-44.15:67 et seq.             17.3-2
# 331      62.1-44.2 et seq.             17.3-2
# 332              63.2-2200           22-245.1
#
# [333 rows x 2 columns]
# url: https://library.municode.com/va/dumfries/codes/code_of_ordinances?nodeId=STLARETA
#                              0                  1
# 0    Code of Virginia  Section  Section this Code
# 1                       1-13.1                1-2
# 2                  1-13.1—1-15                1-2
# 3                       1-13.3                1-2
# 4                     1-13.3:1                1-2
# ..                         ...                ...
# 574              62.1-44.15:62             26-106
# 575           62.1-44.15:63(A)             26-105
# 576      62.1-44.15:67 et seq.           26-165.2
# 577               62.1-44.34:8               30-8
# 578                   62.1-255             70-444
#
# [579 rows x 2 columns]
# This municipality emporia does not host the necessary documents online.
# url: https://library.municode.com/va/essex_county/codes/code_of_ordinances?nodeId=STLARETA
#                              0                   1
# 0    Code of Virginia  Section  Section  this Code
# 1                1-202 et seq.                 1-2
# 2                  1-202—1-257                 1-2
# 3                        1-217                 1-3
# 4              2.2-400 et seq.               34-36
# ..                         ...                 ...
# 171                  58.1-3715               10-60
# 172          58.1-3800 et seq.     Ch. 28, Art. IV
# 173                  58.1-3916                28-2
# 174              62.1-44.15:54              Ch. 16
# 175           62.1-44.15:62(A)                16-8
#
# [176 rows x 2 columns]
# url: https://library.municode.com/va/fairfax/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                  1-10 et seq.                1-2
# 2                        1-13.1                1-2
# 3                        1-13.3                1-2
# 4                      1-13.3:1                1-2
# ..                          ...                ...
# 661                   tit. 63.1             Ch. 70
# 662                   63.2-1515             14-134
# 663                   63.2-1701             14-131
# 664                   63.2-1715             14-131
# 665            65.2-100 et seq.              33-21
#
# [666 rows x 2 columns]
# This municipality fairfax_county does not host the necessary documents online.
# This municipality falls_church does not host the necessary documents online.
# url: https://library.municode.com/va/farmville/codes/code_of_ordinances?nodeId=STATE_LAW_REFERENCE_TABLE
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                        1-13.1                1-2
# 2                        1-13.3                1-2
# 3                 1-13.5—1-13.7                1-2
# 4                        1-13.9                1-5
# ..                          ...                ...
# 458          tit. 62.1, ch. 8.1               10-3
# 459          62.1-115.1 et seq.               10-3
# 460                    63.1-164             25-104
# 461                   63.2-2200              29-81
# 462                   63.2-2200              29-81
#
# [463 rows x 2 columns]
# This municipality fauquier_county does not host the necessary documents online.
# url: https://library.municode.com/va/floyd_county/codes/code_of_ordinances?nodeId=STLARETA
#                            0                        1
# 0    Code of VirginiaSection        Section this Code
# 1                     1-13.3                      1-2
# 2             1-13.6, 1-13.7                      1-2
# 3                     1-13.9                      1-3
# 4           1-13.15, 1-13.16                      1-2
# ..                       ...                      ...
# 251         59.1-142 et seq.         Ch. 30, Art. III
# 252                 59.1-143                    30-63
# 253                 59.1-144  Ch. 30, Art. III,Div. 2
# 254                 59.1-145                    30-62
# 255         59.1-14659.1-147             30-85, 30-86
#
# [256 rows x 2 columns]
# url: https://library.municode.com/va/fluvanna_county/codes/code_of_ordinances?nodeId=CD_COMPARATIVE_TABLEOR
# pass: fluvanna_county empty
# This municipality fluvanna_county does not host the necessary documents online.
# url: https://library.municode.com/va/franklin_county/codes/code_of_ordinances?nodeId=STRETA
#                         0                   1
# 0    Code of Va.  Section  Section  this Code
# 1                  1-13.3                 1-2
# 2                  1-13.9                 1-3
# 3                    1-17                 1-5
# 4                 2.1-344             2-16(6)
# ..                    ...                 ...
# 562         62.1-44.15.54                7-35
# 563          62.1-44.108—         Ch. 9(note)
# 564           62.1-44.112                 NaN
# 565            Title 63.2               2-140
# 566                     —               2-142
#
# [567 rows x 2 columns]
# This municipality gate_city does not host the necessary documents online.
# This municipality gloucester_county does not host the necessary documents online.
# url: https://library.municode.com/va/goochland_county/codes/code_of_ordinances?nodeId=BUERSECOZOSU
# pass: goochland_county empty
# This municipality goochland_county does not host the necessary documents online.
# This municipality gordonsville does not host the necessary documents online.
# This municipality greene_county does not host the necessary documents online.
# url: https://library.municode.com/va/greensville_county/codes/code_of_ordinances?nodeId=COCO_STRETA
# pass: greensville_county empty
# This municipality greensville_county does not host the necessary documents online.
# url: https://library.municode.com/va/halifax_county/codes/code_of_ordinances?nodeId=STLARETA
#      Code of  Virginia halifax_county
# 0        1-202 et seq.            1-2
# 1                1-210            1-2
# 2         1-216, 1-217       1-2, 1-3
# 3                1-222            1-2
# 4         1-227, 1-228            1-2
# ..                 ...            ...
# 476  63.2-1700 et seq.         53-175
# 477                NaN         53-238
# 478                NaN         53-267
# 479           64.1-134         20-238
# 480           64.1-135         20-238
#
# [481 rows x 2 columns]
# url: https://library.municode.com/va/hamilton/codes/code_of_ordinances?nodeId=STLARETA
#                   Virginia Section  this Code
# 0                    1-210                1-2
# 1             1-216, 1-217           1-2, 1-3
# 2                    1-220       Ch. 1 (note)
# 3                    1-223                1-2
# 4             1-227, 1-228                1-2
# ..                     ...                ...
# 124              58.1-3984         8-24, 8-25
# 125              58.1-3993               8-23
# 126       59.1-137 et seq.      Ch. 14 (note)
# 127  62.1-44.15.51 et seq.    Ch. 12, Art. IV
# 128               62.1-45a             24-291
#
# [129 rows x 2 columns]
# This municipality hampton does not host the necessary documents online.
# url: https://library.municode.com/va/hanover_county/codes/code_of_ordinances?nodeId=UNOR
# pass: hanover_county empty
# This municipality hanover_county does not host the necessary documents online.
# This municipality harrisonburg does not host the necessary documents online.
# url: https://library.municode.com/va/haymarket/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                        1-13.1                1-2
# 2                   1-13.1—1-15                1-2
# 3                        1-13.3                1-2
# 4                      1-13.3:1                1-2
# ..                          ...                ...
# 448                   58.1-3993              14-49
# 449            59.1-142 et seq.               30-4
# 450                    59.1-296               58-1
# 451           62.1-44.2 et seq.             Ch. 50
# 452                62.1-44.34:8               19-6
#
# [453 rows x 2 columns]
# This municipality henrico_county does not host the necessary documents online.
# This municipality henry_county does not host the necessary documents online.
# This municipality herndon does not host the necessary documents online.
# This municipality hopewell does not host the necessary documents online.
# url: https://library.municode.com/va/isle_of_wight_county/codes/code_of_ordinances?nodeId=CD_COMPARATIVE_TABLEOR
# pass: isle_of_wight_county empty
# This municipality isle_of_wight_county does not host the necessary documents online.
# url: https://library.municode.com/va/james_city_county/codes/code_of_ordinances?nodeId=COCOTAOR
# pass: james_city_county empty
# This municipality james_city_county does not host the necessary documents online.
# url: https://library.municode.com/va/kenbridge/codes/code_of_ordinances?nodeId=STLARETA
#           Virginia Section  this Code
# 0          1-13.16                1-2
# 1          1-13.28                1-2
# 2    1-202 et seq.           1-2, 1-3
# 3            1-210                1-2
# 4            1-216                1-2
# ..             ...                ...
# 284      58.1-3940             24-174
# 285      58.1-3941              2-182
# 286      58.1-3984             24-174
# 287      58.1-3986             24-173
# 288      58.1-3993             24-173
#
# [289 rows x 2 columns]
# This municipality kilmarnock does not host the necessary documents online.
# url: https://library.municode.com/va/king_and_queen_county/codes/code_of_ordinances?nodeId=STLARETA
#                      0                         1
# 0    Code of  Virginia         Section this Code
# 1               1-13.3                       1-2
# 2       1-13.6, 1-13.7                       1-2
# 3               1-13.9                       1-3
# 4     1-13.15, 1-13.16                       1-2
# ..                 ...                       ...
# 257           62.1-255      Ch. 3, Art. 1, § 3-6
# 258                NaN  Ch. 3, Art. 12, § 3-26B.
# 259   63.1-172 et seq.            Ch. 14, Art. V
# 260   63.1-195 et seq.                    14-121
# 261           63.2-100      Ch. 3, Art. 1, § 3-6
#
# [262 rows x 2 columns]
# url: https://library.municode.com/va/king_george_county/codes/code_of_ordinances?nodeId=STLARETA
#                               0                              1
# 0    Code of  Virginia  Section                Section in Code
# 1                 1-202 et seq.                            1-2
# 2                         1-243                            1-5
# 3               2.1-340 et seq.                           7-39
# 4              2.2-1100 et seq.                           2-24
# ..                          ...                            ...
# 408       62.1-44.15:67 et seq.  App. A, § 8.3,  App. A, § 8.4
# 409                         NaN                 App. A, § 13.8
# 410                62.1-44.19:3         App. A, § 4.6.1, 4.6.2
# 411             62.1-44.19:7(B)              App. A, § 13.14.4
# 412                         195                           5-21
#
# [413 rows x 2 columns]
# url: https://library.municode.com/va/king_william_county/codes/code_of_ordinances?nodeId=STLARETA
#                               0                          1
# 0    Code of  Virginia  Section          Section this Code
# 1                           1-7                       1-10
# 2                           1-9                       1-11
# 3                  1-10 et seq.                       1-10
# 4                          1-12                       1-11
# ..                          ...                        ...
# 647                  62.1-44.18                     Ch. 78
# 648                  62.1-44.20                       6-63
# 649            62.1-254 et seq.  Ch. 86,  Art. IX,  Div. 4
# 650                    62.1-255                     86-402
# 651                      70-144                     70-146
#
# [652 rows x 2 columns]
# This municipality lancaster_county does not host the necessary documents online.
# url: https://library.municode.com/va/lawrenceville/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                1-13.1 et seq.                1-2
# 2                        1-13.9                1-3
# 3                       1-13.15                1-2
# 4                       1-13.19                1-2
# ..                          ...                ...
# 430            59.1-270 et seq.                1-9
# 431                    59.1-283                1-9
# 432            59.1-501 et seq.                1-2
# 433                   tit. 62.1             Ch. 54
# 434           62.1-44.2 et seq.             Ch. 78
#
# [435 rows x 2 columns]
# url: https://library.municode.com/va/leesburg/codes/code_of_ordinances?nodeId=STLARETA
#                          0                   1
# 0        Code of  Virginia  Section  this Code
# 1            1-200 et seq.                 1-2
# 2                    1-220                32-2
# 3              1.8.2-212.1              32-294
# 4         2.2-2700 et seq.                9-37
# ..                     ...                 ...
# 411  62.1-44.15:51 et seq.               14-19
# 412                    NaN               14-41
# 413           62.1-44.19:7               14-23
# 414       tit. 65.2, ch. 6              20-250
# 415       65.2-600 et seq.              20-250
#
# [416 rows x 2 columns]
# url: https://library.municode.com/va/louisa_county/codes/code_of_ordinances?nodeId=STLARETA
#               Virginia Section  this Code
# 0                1-220               74-1
# 1                    —              74-90
# 2      2.1-340 et seq.       Ch. 2 (note)
# 3             tit. 2.2              86-72
# 4     2.2-2426 et seq.              86-72
# ..                 ...                ...
# 480                  —               70-6
# 481   59.1-196 et seq.              26-55
# 482          tit. 62.1              78-77
# 483  62.1-44.2 et seq.              78-77
# 484          tit. 63.2               2-71
#
# [485 rows x 2 columns]
# This municipality lovettsville does not host the necessary documents online.
# url: https://library.municode.com/va/lunenburg_county/codes/code_of_ordinances?nodeId=STLARETA
#                           0                  1
# 0    Code ofVirginiaSection  Section this Code
# 1              1-13 et seq.              Ch. 1
# 2                    1-13.3                1-2
# 3            1-13.6, 1-13.7                1-2
# 4                    1-13.9                1-4
# ..                      ...                ...
# 222            62.1-44.19:3              54-87
# 223                     NaN              54-88
# 224                62.1-255      App. A, § 2-3
# 225                63.1-195      App. A, § 1-2
# 226                64.1-135               70-6
#
# [227 rows x 2 columns]
# This municipality luray does not host the necessary documents online.
# This municipality lynchburg does not host the necessary documents online.
# url: https://library.municode.com/va/madison_county/codes/code_of_ordinances?nodeId=STLARETA
#              Virginia Section  this Code
# 0       1-202 et seq.                1-2
# 1               1-217                1-3
# 2    2.2-3100 et seq.       Ch. 2 (note)
# 3    2.2-4300 et seq.               2-24
# 4            2.2-4304               2-24
# ..                ...                ...
# 205     62.1-44.15:57              14-27
# 206   62.1-44.15:62.A    Ch. 14, Art. II
# 207     62.1-44.15:65    Ch. 14, Art. II
# 208          63.2-301              2-161
# 209          63.2-302              2-161
#
# [210 rows x 2 columns]
# url: https://library.municode.com/va/manassas/codes/code_of_ordinances?nodeId=STLARETA
#                                0                  1
# 0     Code of  Virginia  Section  Section this Code
# 1                            1-1                1-1
# 2                            1-4                1-8
# 3                   1-13 et seq.                1-2
# 4                         1-13.3                1-2
# ...                          ...                ...
# 1306           63.1-67.1 et seq.              94-52
# 1307        63.1-67.6, 63.1-67.7              94-54
# 1308                     63.1-87              94-31
# 1309                   63.2-2200            130-104
# 1310            65.2-100 et seq.               38-1
#
# [1311 rows x 2 columns]
# url: https://library.municode.com/va/manassas_park/codes/code_of_ordinances?nodeId=CD_COMPARATIVE_TABLEOR
# pass: manassas_park empty
# This municipality manassas_park does not host the necessary documents online.
# This municipality marion does not host the necessary documents online.
# url: https://library.municode.com/va/martinsville/codes/code_of_ordinances?nodeId=CO_STRETA
# pass: martinsville empty
# This municipality martinsville does not host the necessary documents online.
# url: https://library.municode.com/va/mecklenburg_county/codes/code_of_ordinances?nodeId=APXCFR
# pass: mecklenburg_county empty
# This municipality mecklenburg_county does not host the necessary documents online.
# This municipality montgomery_county does not host the necessary documents online.
# This municipality mount_jackson does not host the necessary documents online.
# url: https://library.municode.com/va/nelson_county/codes/code_of_ordinances?nodeId=STLARETA
#                         0                  1
# 0    Code of Va.  Section  Section this Code
# 1             1-1 et seq.                1-2
# 2                  1-13.9                1-3
# 3                  1-17.1                1-5
# 4                  2.1-21              Ch. 2
# ..                    ...                ...
# 363          62.1-44.19.3              10-29
# 364                   NaN              10-30
# 365                   NaN              10-40
# 366              63.1-164               6-88
# 367             63.2-2200     App. A, § 23-2
#
# [368 rows x 2 columns]
# url: https://library.municode.com/va/new_kent_county/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                          1-10               46-1
# 2                  1-13 et seq.                1-2
# 3                   1-13.1—1-15               38-3
# 4                        1-13.3                1-2
# ..                          ...                ...
# 599             63.1-38 et seq.             Ch. 54
# 600                   63.1-38.1             Ch. 54
# 601                    ch. 63.2              54-31
# 602                    63.2-302              54-31
# 603                    63.2-305              54-31
#
# [604 rows x 2 columns]
# url: https://library.municode.com/va/new_market/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                        1-13.3                1-2
# 2                      1-13.3:1                1-2
# 3                 1-13.5—1-13.7                1-2
# 4                        1-13.9                1-3
# ..                          ...                ...
# 477                   58.1-3984               22-7
# 478            59.1-137 et seq.             Ch. 30
# 479            59.1-142 et seq.             Ch. 30
# 480                         NaN               30-4
# 481           62.1-44.2 et seq.             Ch. 62
#
# [482 rows x 2 columns]
# This municipality newport_news does not host the necessary documents online.
# url: https://library.municode.com/va/norfolk/codes/code_of_ordinances?nodeId=COCOTA
# pass: norfolk empty
# This municipality norfolk does not host the necessary documents online.
# url: https://library.municode.com/va/norton/codes/code_of_ordinances?nodeId=STLARETA
#     Code of Va.  Section     norton
# 0         1-13.3 et seq.        1-2
# 1                 1-13.9        1-3
# 2       Tit. 2-1, Ch. 21      25-80
# 3             2.1-342(c)      25-80
# 4               2.2-3100     18-567
# ..                   ...        ...
# 589            63.1-43.1  2-74—2-77
# 590            63.1-59.1       2-71
# 591              63.1-60       2-72
# 592             63.2-100      18-42
# 593     65.2-800 et seq.      18-29
#
# [594 rows x 2 columns]
# url: https://library.municode.com/va/onancock/codes/code_of_ordinances?nodeId=STLARETA
#          Code of  Virginia onancock
# 0              1-13.1—1-15      1-2
# 1            1-200 et seq.      1-2
# 2                    1-210      1-2
# 3                    1-213      1-2
# 4                    1-216      1-2
# ..                     ...      ...
# 350                      —   38-287
# 351  62.1-44.15:24 et seq.   38-345
# 352  62.1-44.15:51 et seq.   38-345
# 353          62.1-44.15:72   38-286
# 354          62.1-44.15:74     38-2
#
# [355 rows x 2 columns]
# This municipality orange does not host the necessary documents online.
# This municipality petersburg does not host the necessary documents online.
# This municipality poquoson does not host the necessary documents online.
# This municipality portsmouth does not host the necessary documents online.
# url: https://library.municode.com/va/powhatan_county/codes/code_of_ordinances?nodeId=STLARETA
#     Code of  Virginia  Section powhatan_county
# 0                       1-13.3             1-2
# 1               1-13.6, 1-13.7             1-2
# 2                       1-13.9             1-4
# 3             1-13.15, 1-13.16             1-2
# 4                      1-13.19             1-2
# ..                         ...             ...
# 333           62.1-44.15:63(A)          42-107
# 334               62.1-44.17.1          83-170
# 335                   63.2-100          83-521
# 336          63.2-1700 et seq.          83-521
# 337                  63.2-2200          83-445
#
# [338 rows x 2 columns]
# url: https://library.municode.com/va/prince_edward_county/codes/code_of_ordinances?nodeId=STLARETA
#     Code of  Virginia  Section prince_edward_county
# 0               1-202  et seq.                ch. 1
# 1                     2.2-1159               ch. 18
# 2            2.2-3100  et seq.                ch. 2
# 3            2.2-3700  et seq.                ch. 2
# 4                     3.2-2600                 10-2
# ..                         ...                  ...
# 299              62.1-44.15:35               46-126
# 300              62.1-44.15:40               46-131
# 301     62.1-44.15:54  et seq.               ch. 46
# 302               62.1-44.19:3               46-102
# 303                        NaN               46-103
#
# [304 rows x 2 columns]
# url: https://library.municode.com/va/prince_george_county/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                   1-1 et seq.                1-2
# 2                        1-13.9                1-3
# 3                       1-13.32                1-2
# 4                        1-17.1                1-7
# ..                          ...                ...
# 606            59.1-479 et seq.                1-2
# 607            62.1-190 et seq.               54-6
# 608                    62.1-255           90-330.2
# 609                         NaN             90-662
# 610                    65.2-402             74-221
#
# [611 rows x 2 columns]
# url: https://library.municode.com/va/prince_william_county/codes/code_of_ordinances?nodeId=STLARETA
#                                0                  1
# 0     Code of  Virginia  Section  Section this Code
# 1                    1-13.1—1-15                1-2
# 2                      1-13.39:2             11.1-1
# 3                            NaN               13-1
# 4                            NaN           13-239.2
# ...                          ...                ...
# 1197                         NaN       32-300.02.15
# 1198                    62.1-255          32-200.01
# 1199         63.2-1700—63.2-1738       32-300.02.15
# 1200                   63.2-2200    Ch. 32, Pt. 100
# 1201                         NaN          32-210.16
#
# [1202 rows x 2 columns]
# url: https://library.municode.com/va/pulaski/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                           1-1                1-2
# 2                        1-13.1                1-2
# 3                        1-13.3                1-2
# 4                1-13.6, 1-13.7                1-2
# ..                          ...                ...
# 508               62.1-44.15:27             38-211
# 509                         NaN             38-214
# 510            62.1-44.15:34(A)             38-225
# 511               62.1-44.15:40             38-220
# 512                    62.1-194               14-3
#
# [513 rows x 2 columns]
# This municipality purcellville does not host the necessary documents online.
# This municipality quantico does not host the necessary documents online.
# This municipality radford does not host the necessary documents online.
# This municipality richmond does not host the necessary documents online.
# url: https://library.municode.com/va/roanoke/codes/code_of_ordinances?nodeId=CD_COMPARATIVE_TABLEOR
# pass: roanoke empty
# This municipality roanoke does not host the necessary documents online.
# This municipality roanoke_county does not host the necessary documents online.
# This municipality rockingham_county does not host the necessary documents online.
# url: https://library.municode.com/va/rocky_mount/codes/code_of_ordinances?nodeId=STLARETA
#                                     0                                 1
# 0          Code of  Virginia  Section                 Section this Code
# 1                              1-13.1                               1-2
# 2                         1-13.1—1-15                               1-2
# 3                              1-13.3                               1-2
# 4                      1-13.6, 1-13.7                               1-2
# ..                                ...                               ...
# 220  59.1-142, 59.1-143  34-32, 34-33  59.1-142, 59.1-143  34-32, 34-33
# 221                          59.1-146                             34-31
# 222                          59.1-147                             34-35
# 223          63.2-100  App. A, Art. 4          63.2-100  App. A, Art. 4
# 224         63.2-2200  App. A, Art. 6         63.2-2200  App. A, Art. 6
#
# [225 rows x 2 columns]
# This municipality salem does not host the necessary documents online.
# url: https://library.municode.com/va/shenandoah/codes/code_of_ordinances?nodeId=STATE_LAW_REFERENCE_TABLE
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                        1-13.1                1-2
# 2                   1-13.1—1-15                1-2
# 3                        1-13.3                1-2
# 4                      1-13.3:1                1-2
# ..                          ...                ...
# 571                         NaN              30-17
# 572            59.1-479 et seq.                1-2
# 573   59.1-538—59.1-549 et seq.              50-72
# 574            62.1-442 et seq.    Ch. 74, Art. II
# 575                   tit. 65.2               2-73
#
# [576 rows x 2 columns]
# url: https://library.municode.com/va/smithfield/codes/code_of_ordinances?nodeId=STLARETA
# This municipality smithfield does not host the necessary documents online.
# This municipality smyth_county does not host the necessary documents online.
# url: https://library.municode.com/va/south_boston/codes/code_of_ordinances?nodeId=STLARETA
#                Virginia Section  this Code
# 0                 1-210                1-2
# 1                 1-216                1-2
# 2                 1-217                1-3
# 3                 1-222                1-2
# 4                 1-223                1-2
# ..                  ...                ...
# 743          62.1-44.34             26-142
# 744            63.2-100               58-3
# 745  title 63.2, ch. 17               58-3
# 746   63.2-1700 et seq.               58-3
# 747           63.2-1704               58-3
#
# [748 rows x 2 columns]
# This municipality south_hill does not host the necessary documents online.
# url: https://library.municode.com/va/southampton_county/codes/code_of_ordinances?nodeId=STLARETA
#                         0                  1
# 0    Code of Va.  Section  Section this Code
# 1                    1-10                1-6
# 2                  1-13.3                1-2
# 3                1-13.3:1                1-2
# 4          1-13.6, 1-13.7                1-2
# ..                    ...                ...
# 485            62.1-44.26            13.5-12
# 486    62.1-115.1 et seq.                6-2
# 487             63.2-2200               18-1
# 488              64.1-134             1-13.3
# 489              64.1-135             1-13.3
#
# [490 rows x 2 columns]
# url: https://library.municode.com/va/spotsylvania_county/codes/code_of_ordinances?nodeId=STLARETA
# This municipality spotsylvania_county does not host the necessary documents online.
# url: https://library.municode.com/va/st._paul/codes/code_of_ordinances?nodeId=STLARETA
#              Virginia Section  this Code
# 0               1-200                1-1
# 1       1-202 et seq.                1-2
# 2               1-217                1-5
# 3    2.2-3700 et seq.       Ch. 2 (note)
# 4    2.2-3100 et seq.     Ch. 2, Art. IV
# ..                ...                ...
# 101         58.1-3906              20-79
# 102         58.1-3916                8-3
# 103         58.1-3940                8-5
# 104                 —    Ch. 20, Art. IV
# 105         58.1-3984           8-5, 8-6
#
# [106 rows x 2 columns]
# url: https://library.municode.com/va/stafford_county/codes/code_of_ordinances?nodeId=STRETA
#                                   0                               1    2
# 0              Code of Va.  Section              Section  this Code  NaN
# 1                             1-202                             1-2  NaN
# 2                  1-202—1-257  1-2                1-202—1-257  1-2  NaN
# 3                             1-220                          15-136  NaN
# 4          Tit. 2.2, Ch. 31, Art. 7                           2-102  NaN
# ..                              ...                             ...  ...
# 597                             NaN                           28-25  NaN
# 598  62.1-44.15:350 et seq.  21.5-6  62.1-44.15:350 et seq.  21.5-6  NaN
# 599                        62.1-182                           17-29  NaN
# 600                        63.2-100                           28-25  NaN
# 601        63.2-1700 et seq.  28-25        63.2-1700 et seq.  28-25  NaN
#
# [602 rows x 3 columns]
# url: https://library.municode.com/va/strasburg/codes/code_of_ordinances?nodeId=STLARETA
#               Virginia        strasburg
# 0         1-13 et seq.              1-2
# 1               1-13.9              1-4
# 2              1-13.19              1-2
# 3              1-13.25              2-1
# 4                  NaN            2-219
# ..                 ...              ...
# 470           59.1-147            42-91
# 471           59.1-148  Ch. 42, Art. IV
# 472                NaN            42-92
# 473   59.1-501 et seq.              1-2
# 474  62.1-44.2 et seq.           Ch. 86
#
# [475 rows x 2 columns]
# This municipality suffolk does not host the necessary documents online.
# url: https://library.municode.com/va/surry_county/codes/code_of_ordinances?nodeId=STLARETA
#                              0                 1
# 0    Code of Virginia  Section  Section  in Code
# 1                1-200 et seq.               1-2
# 2                        1-217               1-3
# 3             2.2-4300 et seq.     Ch. 2, Art. V
# 4                          NaN      2-148, 2-149
# ..                         ...               ...
# 329                  58.1-3993            16-114
# 330          62.1-44.2 et seq.   App. A, § 4-901
# 331               62.1-44.19:3  Ch. 10, Art. III
# 332                        NaN             10-53
# 333                  68-3700.1            16-109
#
# [334 rows x 2 columns]
# url: https://library.municode.com/va/sussex_county/codes/code_of_ordinances?nodeId=STLARETA
#              Virginia Section  this Code
# 0       1-200 et seq.                1-2
# 1           2.2-614.1              28-25
# 2            2.2-3300       Ch. 2 (note)
# 3            3.2-2600                4-1
# 4            3.2-5900                4-1
# ..                ...                ...
# 293     62.1-44.15:63              14-28
# 294      62.1-44.19:3   Ch. 14, Art. III
# 295          62.1-194      Ch. 22 (note)
# 296                 —    Ch. 22, Art. II
# 297  65.2-800 et seq.             28-365
#
# [298 rows x 2 columns]
# url: https://library.municode.com/va/tappahannock/codes/code_of_ordinances?nodeId=STLARETA
# This municipality tappahannock does not host the necessary documents online.
# url: https://library.municode.com/va/tazewell/codes/code_of_ordinances?nodeId=STLARETA
#                               0                  1
# 0    Code of  Virginia  Section  Section this Code
# 1                        1-13.3                1-2
# 2                      1-13.3:1                1-2
# 3                 1-13.5—1-13.7                1-2
# 4                        1-13.9                1-3
# ..                          ...                ...
# 387                    59.1-144    Ch. 11, Art. II
# 388                    59.1-148    Ch. 11, Art. II
# 389            59.1-538 et seq.             10-103
# 390           62.1-44.2 et seq.             Ch. 22
# 391                    63.1-195             23-116
#
# [392 rows x 2 columns]
# This municipality tazewell_county does not host the necessary documents online.
# url: https://library.municode.com/va/victoria/codes/code_of_ordinances?nodeId=STLARETA
#               Virginia victoria
# 0                1-200    Ch. 1
# 1                1-210      1-5
# 2                1-216      1-5
# 3                1-220     1-16
# 4                1-227      1-5
# ..                 ...      ...
# 184                  —     8-63
# 185   59.1-137 et seq.   Ch. 16
# 186           63.2-100     34-3
# 187  63.2-1700 et seq.     34-3
# 188          63.2-1704     34-3
#
# [189 rows x 2 columns]
# This municipality vienna does not host the necessary documents online.
# This municipality vinton does not host the necessary documents online.
# This municipality virginia does not host the necessary documents online.
# This municipality virginia_beach does not host the necessary documents online.
# This municipality warrenton does not host the necessary documents online.
# url: https://library.municode.com/va/washington_county/codes/code_of_ordinances?nodeId=STLARETA
#                      0                  1
# 0    Code of  Virginia  Section this Code
# 1               1-13.3                1-2
# 2               1-13.6                1-2
# 3               1-13.7                1-2
# 4               1-13.9                1-3
# ..                 ...                ...
# 690       62.1-44.18:3             52-174
# 691                NaN              63-47
# 692       62.1-44.19:3    Ch. 30, Art. VI
# 693         62.1-44.32             63-198
# 694                NaN             63-204
#
# [695 rows x 2 columns]
# url: https://library.municode.com/va/waynesboro/codes/code_of_ordinances?nodeId=STLARETA
#                              0                  1
# 0    Code of Virginia  Section  Section this Code
# 1                 1-10 et seq.                1-2
# 2                       1-13.3                1-2
# 3               1-13.6, 1-13.7                1-2
# 4             1-13.15, 1-13.16                1-2
# ..                         ...                ...
# 470                    63.1-59             Ch. 64
# 471           63.1-183 et seq.             Ch. 64
# 472                   64.2-509             78-3.1
# 473                   64.2-510             78-3.1
# 474                      66-29              2-416
#
# [475 rows x 2 columns]
# url: https://library.municode.com/va/west_point/codes/code_of_ordinances?nodeId=STLARETA
#                           0                  1
# 0    Code ofVirginiaSection  Section this Code
# 1             1-202 et seq.                1-2
# 2                     1-217                1-3
# 3          2.2-4300 et seq.             Ch. 42
# 4                  tit. 3.1              10-11
# ..                      ...                ...
# 242            58.1-3814(J)              58-46
# 243               58.1-3840              58-73
# 244               58.1-3916         58-7, 58-8
# 245       58.1-3940 et seq.               46-5
# 246       58.1-3965 et seq.               46-5
#
# [247 rows x 2 columns]
# This municipality westmoreland_county does not host the necessary documents online.
# This municipality williamsburg does not host the necessary documents online.
# This municipality winchester does not host the necessary documents online.
# url: https://library.municode.com/va/windsor/codes/code_of_ordinances?nodeId=STLARETA
#                              0                  1
# 0   Code of  Virginia  Section  Section this Code
# 1                  1-13—1-15.1                1-1
# 2             2.2-3708.2(A)(3)                9-4
# 3                   3.1-796.66               40-2
# 4             13.1-501 et seq.               89-2
# ..                         ...                ...
# 74                   58.1-3906             130-34
# 75                   58.1-3916               89-3
# 76                   58.1-3919             130-64
# 77                   58.1-3980               89-5
# 78                    62.1-45a             145-11
#
# [79 rows x 2 columns]
# This municipality wise_county does not host the necessary documents online.
# This municipality woodstock does not host the necessary documents online.
# This municipality wytheville does not host the necessary documents online.
